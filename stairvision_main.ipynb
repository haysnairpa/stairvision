# %% [markdown]
# <a href="https://colab.research.google.com/github/haysnairpa/stairvision/blob/main/stairvision_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics opencv-python-headless numpy
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.177-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.177-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 28.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 40.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 41.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.177 ultralytics-thop-2.0.15

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %%
seg_model_path = "src/model/best_stair_handrail_model.pt"
pose_model_path = "src/model/best_pose_model.pt"

seg_model = YOLO(seg_model_path)
pose_model = YOLO(pose_model_path)

# %%
import os

video_path = r"D:\Aldi\stairvision\src\dataset\east\videos\Copy of Copy of IMG_3086.MOV"
output_dir = r"D:\Aldi\stairvision\src\dataset\east\videos\output_videos"
output_prefix = "output_"

os.makedirs(output_dir, exist_ok=True)

base_name = os.path.basename(video_path)
base_name_no_ext, ext = os.path.splitext(base_name)

new_file_name = f"{output_prefix}{base_name_no_ext}{ext}"
output_path = os.path.join(output_dir, new_file_name)

counter = 1
while os.path.exists(output_path):
    new_file_name = f"{output_prefix}{base_name_no_ext} ({counter}){ext}"
    output_path = os.path.join(output_dir, new_file_name)
    counter += 1

print(f"output path: {output_path}")
# Out:
# output path: D:\Aldi\stairvision\src\dataset\east\videos\output_videos\output_Copy of Copy of IMG_3086 (2).MOV

# %%
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise RuntimeError(f"❌: {video_path}")

# %%
cap = cv2.VideoCapture(video_path)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# %%
import time
import cv2
import numpy as np

start_time = time.time()

DILATE_KERNEL_SIZE = 5
CLOSE_KERNEL_SIZE = 5
KP_CONF_THRESH = 0.25
HAND_RADIUS = max(5, int(0.015 * max(width, height)))
HAND_OVERLAP_RATIO = 0.3

frame_num = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_orig = frame.copy()

    seg_results = seg_model.predict(frame, conf=0.4, verbose=False)
    handrail_mask = np.zeros((height, width), dtype=np.uint8)

    for r in seg_results:
        if r.masks is not None:
            for mask_poly, cls in zip(r.masks.xy, r.boxes.cls):
                if int(cls) == 0:
                    poly = np.array(mask_poly, dtype=np.int32)
                    cv2.fillPoly(handrail_mask, [poly], 255)

    close_kernel = np.ones((CLOSE_KERNEL_SIZE, CLOSE_KERNEL_SIZE), np.uint8)
    handrail_mask = cv2.morphologyEx(handrail_mask, cv2.MORPH_CLOSE, close_kernel)
    dilate_kernel = np.ones((DILATE_KERNEL_SIZE, DILATE_KERNEL_SIZE), np.uint8)
    handrail_mask = cv2.dilate(handrail_mask, dilate_kernel, iterations=1)

    pose_results = pose_model.predict(frame_orig, conf=0.25, verbose=False)

    frame_vis = frame.copy()

    for r in pose_results:
        if r.keypoints is None:
            continue

        kpts_xy = r.keypoints.xy.cpu().numpy()
        try:
            kpts_conf = r.keypoints.conf.cpu().numpy()
        except Exception:
            kpts_conf = np.ones((kpts_xy.shape[0], kpts_xy.shape[1]))

        for person_idx in range(kpts_xy.shape[0]):
            person_kpts = kpts_xy[person_idx]
            person_conf = kpts_conf[person_idx]

            hands = []
            hands_conf = []

            if person_kpts.shape[0] > 9:
                hands.append(person_kpts[9])
                hands_conf.append(person_conf[9])
            if person_kpts.shape[0] > 10:
                hands.append(person_kpts[10])
                hands_conf.append(person_conf[10])

            holding = False
            for (hx, hy), conf_val in zip(hands, hands_conf):
                if conf_val < KP_CONF_THRESH:
                    continue
                x, y = int(hx), int(hy)
                if not (0 <= x < width and 0 <= y < height):
                    continue

                y_grid, x_grid = np.ogrid[:height, :width]
                mask_circle = (x_grid - x) ** 2 + (y_grid - y) ** 2 <= HAND_RADIUS ** 2
                inside_mask = np.logical_and(mask_circle, handrail_mask > 0)
                overlap_ratio = inside_mask.sum() / mask_circle.sum()

                if overlap_ratio >= HAND_OVERLAP_RATIO:
                    holding = True
                    cv2.circle(frame_vis, (x, y), 6, (0, 255, 0), -1)
                else:
                    cv2.circle(frame_vis, (x, y), 6, (0, 0, 255), -1)

            label_pos = (int(person_kpts[0][0]), int(person_kpts[0][1]) - 10) if person_kpts.shape[0] > 0 else (10, 30)
            if holding:
                cv2.putText(frame_vis, "Holding Handrail", label_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
            else:
                cv2.putText(frame_vis, "Not Holding", label_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    out.write(frame_vis)
    frame_num += 1

    elapsed = time.time() - start_time
    fps_proc = frame_num / elapsed if elapsed > 0 else 0
    eta = (total_frames - frame_num) / fps_proc if fps_proc > 0 else 0
    print(f"Frame {frame_num}/{total_frames} | {fps_proc:.2f} FPS | ETA: {eta/60:.1f} min", flush=True)

cap.release()
out.release()
print(f"video saved to: {output_path}")
# Out:
# Frame 1/303 | 0.23 FPS | ETA: 22.2 min
# Frame 2/303 | 0.42 FPS | ETA: 11.9 min
# Frame 3/303 | 0.59 FPS | ETA: 8.5 min
# Frame 4/303 | 0.73 FPS | ETA: 6.8 min
# Frame 5/303 | 0.86 FPS | ETA: 5.8 min
# Frame 6/303 | 0.98 FPS | ETA: 5.0 min
# Frame 7/303 | 1.08 FPS | ETA: 4.5 min
# Frame 8/303 | 1.17 FPS | ETA: 4.2 min
# Frame 9/303 | 1.26 FPS | ETA: 3.9 min
# Frame 10/303 | 1.32 FPS | ETA: 3.7 min
# Frame 11/303 | 1.39 FPS | ETA: 3.5 min
# Frame 12/303 | 1.44 FPS | ETA: 3.4 min
# Frame 13/303 | 1.49 FPS | ETA: 3.3 min
# Frame 14/303 | 1.53 FPS | ETA: 3.2 min
# Frame 15/303 | 1.57 FPS | ETA: 3.1 min
# Frame 16/303 | 1.60 FPS | ETA: 3.0 min
# Frame 17/303 | 1.64 FPS | ETA: 2.9 min
# Frame 18/303 | 1.67 FPS | ETA: 2.8 min
# Frame 19/303 | 1.70 FPS | ETA: 2.8 min
# Frame 20/303 | 1.73 FPS | ETA: 2.7 min
# Frame 21/303 | 1.76 FPS | ETA: 2.7 min
# Frame 22/303 | 1.79 FPS | ETA: 2.6 min
# Frame 23/303 | 1.81 FPS | ETA: 2.6 min
# Frame 24/303 | 1.83 FPS | ETA: 2.5 min
# Frame 25/303 | 1.85 FPS | ETA: 2.5 min
# Frame 26/303 | 1.86 FPS | ETA: 2.5 min
# Frame 27/303 | 1.88 FPS | ETA: 2.4 min
# Frame 28/303 | 1.90 FPS | ETA: 2.4 min
# Frame 29/303 | 1.91 FPS | ETA: 2.4 min
# Frame 30/303 | 1.93 FPS | ETA: 2.4 min
# Frame 31/303 | 1.93 FPS | ETA: 2.3 min
# Frame 32/303 | 1.96 FPS | ETA: 2.3 min
# Frame 33/303 | 1.98 FPS | ETA: 2.3 min
# Frame 34/303 | 1.99 FPS | ETA: 2.3 min
# Frame 35/303 | 2.01 FPS | ETA: 2.2 min
# Frame 36/303 | 2.03 FPS | ETA: 2.2 min
# Frame 37/303 | 2.04 FPS | ETA: 2.2 min
# Frame 38/303 | 2.05 FPS | ETA: 2.2 min
# Frame 39/303 | 2.06 FPS | ETA: 2.1 min
# Frame 40/303 | 2.06 FPS | ETA: 2.1 min
# Frame 41/303 | 2.07 FPS | ETA: 2.1 min
# Frame 42/303 | 2.07 FPS | ETA: 2.1 min
# Frame 43/303 | 2.08 FPS | ETA: 2.1 min
# Frame 44/303 | 2.08 FPS | ETA: 2.1 min
# Frame 45/303 | 2.09 FPS | ETA: 2.1 min
# Frame 46/303 | 2.10 FPS | ETA: 2.0 min
# Frame 47/303 | 2.10 FPS | ETA: 2.0 min
# Frame 48/303 | 2.10 FPS | ETA: 2.0 min
# Frame 49/303 | 2.11 FPS | ETA: 2.0 min
# Frame 50/303 | 2.11 FPS | ETA: 2.0 min
# Frame 51/303 | 2.12 FPS | ETA: 2.0 min
# Frame 52/303 | 2.12 FPS | ETA: 2.0 min
# Frame 53/303 | 2.13 FPS | ETA: 2.0 min
# Frame 54/303 | 2.14 FPS | ETA: 1.9 min
# Frame 55/303 | 2.15 FPS | ETA: 1.9 min
# Frame 56/303 | 2.15 FPS | ETA: 1.9 min
# Frame 57/303 | 2.16 FPS | ETA: 1.9 min
# Frame 58/303 | 2.17 FPS | ETA: 1.9 min
# Frame 59/303 | 2.17 FPS | ETA: 1.9 min
# Frame 60/303 | 2.18 FPS | ETA: 1.9 min
# Frame 61/303 | 2.18 FPS | ETA: 1.8 min
# Frame 62/303 | 2.19 FPS | ETA: 1.8 min
# Frame 63/303 | 2.20 FPS | ETA: 1.8 min
# Frame 64/303 | 2.20 FPS | ETA: 1.8 min
# Frame 65/303 | 2.20 FPS | ETA: 1.8 min
# Frame 66/303 | 2.21 FPS | ETA: 1.8 min
# Frame 67/303 | 2.21 FPS | ETA: 1.8 min
# Frame 68/303 | 2.22 FPS | ETA: 1.8 min
# Frame 69/303 | 2.22 FPS | ETA: 1.8 min
# Frame 70/303 | 2.22 FPS | ETA: 1.7 min
# Frame 71/303 | 2.23 FPS | ETA: 1.7 min
# Frame 72/303 | 2.23 FPS | ETA: 1.7 min
# Frame 73/303 | 2.23 FPS | ETA: 1.7 min
# Frame 74/303 | 2.24 FPS | ETA: 1.7 min
# Frame 75/303 | 2.24 FPS | ETA: 1.7 min
# Frame 76/303 | 2.24 FPS | ETA: 1.7 min
# Frame 77/303 | 2.24 FPS | ETA: 1.7 min
# Frame 78/303 | 2.25 FPS | ETA: 1.7 min
# Frame 79/303 | 2.25 FPS | ETA: 1.7 min
# Frame 80/303 | 2.25 FPS | ETA: 1.7 min
# Frame 81/303 | 2.25 FPS | ETA: 1.6 min
# Frame 82/303 | 2.26 FPS | ETA: 1.6 min
# Frame 83/303 | 2.26 FPS | ETA: 1.6 min
# Frame 84/303 | 2.26 FPS | ETA: 1.6 min
# Frame 85/303 | 2.27 FPS | ETA: 1.6 min
# Frame 86/303 | 2.26 FPS | ETA: 1.6 min
# Frame 87/303 | 2.27 FPS | ETA: 1.6 min
# Frame 88/303 | 2.27 FPS | ETA: 1.6 min
# Frame 89/303 | 2.27 FPS | ETA: 1.6 min
# Frame 90/303 | 2.27 FPS | ETA: 1.6 min
# Frame 91/303 | 2.28 FPS | ETA: 1.6 min
# Frame 92/303 | 2.28 FPS | ETA: 1.5 min
# Frame 93/303 | 2.28 FPS | ETA: 1.5 min
# Frame 94/303 | 2.29 FPS | ETA: 1.5 min
# Frame 95/303 | 2.29 FPS | ETA: 1.5 min
# Frame 96/303 | 2.29 FPS | ETA: 1.5 min
# Frame 97/303 | 2.29 FPS | ETA: 1.5 min
# Frame 98/303 | 2.30 FPS | ETA: 1.5 min
# Frame 99/303 | 2.30 FPS | ETA: 1.5 min
# Frame 100/303 | 2.30 FPS | ETA: 1.5 min
# Frame 101/303 | 2.30 FPS | ETA: 1.5 min
# Frame 102/303 | 2.30 FPS | ETA: 1.5 min
# Frame 103/303 | 2.30 FPS | ETA: 1.4 min
# Frame 104/303 | 2.31 FPS | ETA: 1.4 min
# Frame 105/303 | 2.31 FPS | ETA: 1.4 min
# Frame 106/303 | 2.30 FPS | ETA: 1.4 min
# Frame 107/303 | 2.31 FPS | ETA: 1.4 min
# Frame 108/303 | 2.32 FPS | ETA: 1.4 min
# Frame 109/303 | 2.32 FPS | ETA: 1.4 min
# Frame 110/303 | 2.33 FPS | ETA: 1.4 min
# Frame 111/303 | 2.33 FPS | ETA: 1.4 min
# Frame 112/303 | 2.33 FPS | ETA: 1.4 min
# Frame 113/303 | 2.33 FPS | ETA: 1.4 min
# Frame 114/303 | 2.34 FPS | ETA: 1.3 min
# Frame 115/303 | 2.34 FPS | ETA: 1.3 min
# Frame 116/303 | 2.34 FPS | ETA: 1.3 min
# Frame 117/303 | 2.34 FPS | ETA: 1.3 min
# Frame 118/303 | 2.34 FPS | ETA: 1.3 min
# Frame 119/303 | 2.35 FPS | ETA: 1.3 min
# Frame 120/303 | 2.35 FPS | ETA: 1.3 min
# Frame 121/303 | 2.35 FPS | ETA: 1.3 min
# Frame 122/303 | 2.35 FPS | ETA: 1.3 min
# Frame 123/303 | 2.35 FPS | ETA: 1.3 min
# Frame 124/303 | 2.35 FPS | ETA: 1.3 min
# Frame 125/303 | 2.36 FPS | ETA: 1.3 min
# Frame 126/303 | 2.36 FPS | ETA: 1.3 min
# Frame 127/303 | 2.36 FPS | ETA: 1.2 min
# Frame 128/303 | 2.36 FPS | ETA: 1.2 min
# Frame 129/303 | 2.36 FPS | ETA: 1.2 min
# Frame 130/303 | 2.36 FPS | ETA: 1.2 min
# Frame 131/303 | 2.36 FPS | ETA: 1.2 min
# Frame 132/303 | 2.36 FPS | ETA: 1.2 min
# Frame 133/303 | 2.36 FPS | ETA: 1.2 min
# Frame 134/303 | 2.37 FPS | ETA: 1.2 min
# Frame 135/303 | 2.37 FPS | ETA: 1.2 min
# Frame 136/303 | 2.37 FPS | ETA: 1.2 min
# Frame 137/303 | 2.37 FPS | ETA: 1.2 min
# Frame 138/303 | 2.37 FPS | ETA: 1.2 min
# Frame 139/303 | 2.37 FPS | ETA: 1.2 min
# Frame 140/303 | 2.37 FPS | ETA: 1.1 min
# Frame 141/303 | 2.37 FPS | ETA: 1.1 min
# Frame 142/303 | 2.38 FPS | ETA: 1.1 min
# Frame 143/303 | 2.38 FPS | ETA: 1.1 min
# Frame 144/303 | 2.38 FPS | ETA: 1.1 min
# Frame 145/303 | 2.38 FPS | ETA: 1.1 min
# Frame 146/303 | 2.38 FPS | ETA: 1.1 min
# Frame 147/303 | 2.38 FPS | ETA: 1.1 min
# Frame 148/303 | 2.38 FPS | ETA: 1.1 min
# Frame 149/303 | 2.38 FPS | ETA: 1.1 min
# Frame 150/303 | 2.38 FPS | ETA: 1.1 min
# Frame 151/303 | 2.39 FPS | ETA: 1.1 min
# Frame 152/303 | 2.39 FPS | ETA: 1.1 min
# Frame 153/303 | 2.39 FPS | ETA: 1.0 min
# Frame 154/303 | 2.39 FPS | ETA: 1.0 min
# Frame 155/303 | 2.39 FPS | ETA: 1.0 min
# Frame 156/303 | 2.39 FPS | ETA: 1.0 min
# Frame 157/303 | 2.39 FPS | ETA: 1.0 min
# Frame 158/303 | 2.39 FPS | ETA: 1.0 min
# Frame 159/303 | 2.39 FPS | ETA: 1.0 min
# Frame 160/303 | 2.39 FPS | ETA: 1.0 min
# Frame 161/303 | 2.39 FPS | ETA: 1.0 min
# Frame 162/303 | 2.39 FPS | ETA: 1.0 min
# Frame 163/303 | 2.39 FPS | ETA: 1.0 min
# Frame 164/303 | 2.40 FPS | ETA: 1.0 min
# Frame 165/303 | 2.40 FPS | ETA: 1.0 min
# Frame 166/303 | 2.40 FPS | ETA: 1.0 min
# Frame 167/303 | 2.40 FPS | ETA: 0.9 min
# Frame 168/303 | 2.40 FPS | ETA: 0.9 min
# Frame 169/303 | 2.40 FPS | ETA: 0.9 min
# Frame 170/303 | 2.39 FPS | ETA: 0.9 min
# Frame 171/303 | 2.39 FPS | ETA: 0.9 min
# Frame 172/303 | 2.40 FPS | ETA: 0.9 min
# Frame 173/303 | 2.40 FPS | ETA: 0.9 min
# Frame 174/303 | 2.40 FPS | ETA: 0.9 min
# Frame 175/303 | 2.41 FPS | ETA: 0.9 min
# Frame 176/303 | 2.41 FPS | ETA: 0.9 min
# Frame 177/303 | 2.41 FPS | ETA: 0.9 min
# Frame 178/303 | 2.41 FPS | ETA: 0.9 min
# Frame 179/303 | 2.41 FPS | ETA: 0.9 min
# Frame 180/303 | 2.41 FPS | ETA: 0.8 min
# Frame 181/303 | 2.41 FPS | ETA: 0.8 min
# Frame 182/303 | 2.41 FPS | ETA: 0.8 min
# Frame 183/303 | 2.41 FPS | ETA: 0.8 min
# Frame 184/303 | 2.41 FPS | ETA: 0.8 min
# Frame 185/303 | 2.42 FPS | ETA: 0.8 min
# Frame 186/303 | 2.42 FPS | ETA: 0.8 min
# Frame 187/303 | 2.42 FPS | ETA: 0.8 min
# Frame 188/303 | 2.42 FPS | ETA: 0.8 min
# Frame 189/303 | 2.42 FPS | ETA: 0.8 min
# Frame 190/303 | 2.42 FPS | ETA: 0.8 min
# Frame 191/303 | 2.42 FPS | ETA: 0.8 min
# Frame 192/303 | 2.42 FPS | ETA: 0.8 min
# Frame 193/303 | 2.42 FPS | ETA: 0.8 min
# Frame 194/303 | 2.41 FPS | ETA: 0.8 min
# Frame 195/303 | 2.42 FPS | ETA: 0.7 min
# Frame 196/303 | 2.42 FPS | ETA: 0.7 min
# Frame 197/303 | 2.41 FPS | ETA: 0.7 min
# Frame 198/303 | 2.42 FPS | ETA: 0.7 min
# Frame 199/303 | 2.42 FPS | ETA: 0.7 min
# Frame 200/303 | 2.42 FPS | ETA: 0.7 min
# Frame 201/303 | 2.42 FPS | ETA: 0.7 min
# Frame 202/303 | 2.42 FPS | ETA: 0.7 min
# Frame 203/303 | 2.42 FPS | ETA: 0.7 min
# Frame 204/303 | 2.42 FPS | ETA: 0.7 min
# Frame 205/303 | 2.42 FPS | ETA: 0.7 min
# Frame 206/303 | 2.42 FPS | ETA: 0.7 min
# Frame 207/303 | 2.42 FPS | ETA: 0.7 min
# Frame 208/303 | 2.42 FPS | ETA: 0.7 min
# Frame 209/303 | 2.42 FPS | ETA: 0.6 min
# Frame 210/303 | 2.42 FPS | ETA: 0.6 min
# Frame 211/303 | 2.42 FPS | ETA: 0.6 min
# Frame 212/303 | 2.43 FPS | ETA: 0.6 min
# Frame 213/303 | 2.43 FPS | ETA: 0.6 min
# Frame 214/303 | 2.43 FPS | ETA: 0.6 min
# Frame 215/303 | 2.43 FPS | ETA: 0.6 min
# Frame 216/303 | 2.43 FPS | ETA: 0.6 min
# Frame 217/303 | 2.43 FPS | ETA: 0.6 min
# Frame 218/303 | 2.43 FPS | ETA: 0.6 min
# Frame 219/303 | 2.43 FPS | ETA: 0.6 min
# Frame 220/303 | 2.43 FPS | ETA: 0.6 min
# Frame 221/303 | 2.43 FPS | ETA: 0.6 min
# Frame 222/303 | 2.43 FPS | ETA: 0.6 min
# Frame 223/303 | 2.43 FPS | ETA: 0.5 min
# Frame 224/303 | 2.43 FPS | ETA: 0.5 min
# Frame 225/303 | 2.43 FPS | ETA: 0.5 min
# Frame 226/303 | 2.43 FPS | ETA: 0.5 min
# Frame 227/303 | 2.43 FPS | ETA: 0.5 min
# Frame 228/303 | 2.43 FPS | ETA: 0.5 min
# Frame 229/303 | 2.44 FPS | ETA: 0.5 min
# Frame 230/303 | 2.44 FPS | ETA: 0.5 min
# Frame 231/303 | 2.44 FPS | ETA: 0.5 min
# Frame 232/303 | 2.44 FPS | ETA: 0.5 min
# Frame 233/303 | 2.44 FPS | ETA: 0.5 min
# Frame 234/303 | 2.44 FPS | ETA: 0.5 min
# Frame 235/303 | 2.44 FPS | ETA: 0.5 min
# Frame 236/303 | 2.44 FPS | ETA: 0.5 min
# Frame 237/303 | 2.44 FPS | ETA: 0.5 min
# Frame 238/303 | 2.44 FPS | ETA: 0.4 min
# Frame 239/303 | 2.44 FPS | ETA: 0.4 min
# Frame 240/303 | 2.44 FPS | ETA: 0.4 min
# Frame 241/303 | 2.45 FPS | ETA: 0.4 min
# Frame 242/303 | 2.45 FPS | ETA: 0.4 min
# Frame 243/303 | 2.45 FPS | ETA: 0.4 min
# Frame 244/303 | 2.45 FPS | ETA: 0.4 min
# Frame 245/303 | 2.45 FPS | ETA: 0.4 min
# Frame 246/303 | 2.45 FPS | ETA: 0.4 min
# Frame 247/303 | 2.45 FPS | ETA: 0.4 min
# Frame 248/303 | 2.45 FPS | ETA: 0.4 min
# Frame 249/303 | 2.45 FPS | ETA: 0.4 min
# Frame 250/303 | 2.45 FPS | ETA: 0.4 min
# Frame 251/303 | 2.45 FPS | ETA: 0.4 min
# Frame 252/303 | 2.45 FPS | ETA: 0.3 min
# Frame 253/303 | 2.45 FPS | ETA: 0.3 min
# Frame 254/303 | 2.45 FPS | ETA: 0.3 min
# Frame 255/303 | 2.45 FPS | ETA: 0.3 min
# Frame 256/303 | 2.45 FPS | ETA: 0.3 min
# Frame 257/303 | 2.45 FPS | ETA: 0.3 min
# Frame 258/303 | 2.45 FPS | ETA: 0.3 min
# Frame 259/303 | 2.45 FPS | ETA: 0.3 min
# Frame 260/303 | 2.46 FPS | ETA: 0.3 min
# Frame 261/303 | 2.46 FPS | ETA: 0.3 min
# Frame 262/303 | 2.46 FPS | ETA: 0.3 min
# Frame 263/303 | 2.46 FPS | ETA: 0.3 min
# Frame 264/303 | 2.46 FPS | ETA: 0.3 min
# Frame 265/303 | 2.46 FPS | ETA: 0.3 min
# Frame 266/303 | 2.46 FPS | ETA: 0.3 min
# Frame 267/303 | 2.46 FPS | ETA: 0.2 min
# Frame 268/303 | 2.46 FPS | ETA: 0.2 min
# Frame 269/303 | 2.46 FPS | ETA: 0.2 min
# Frame 270/303 | 2.47 FPS | ETA: 0.2 min
# Frame 271/303 | 2.47 FPS | ETA: 0.2 min
# Frame 272/303 | 2.47 FPS | ETA: 0.2 min
# Frame 273/303 | 2.47 FPS | ETA: 0.2 min
# Frame 274/303 | 2.47 FPS | ETA: 0.2 min
# Frame 275/303 | 2.47 FPS | ETA: 0.2 min
# Frame 276/303 | 2.47 FPS | ETA: 0.2 min
# Frame 277/303 | 2.47 FPS | ETA: 0.2 min
# Frame 278/303 | 2.47 FPS | ETA: 0.2 min
# Frame 279/303 | 2.47 FPS | ETA: 0.2 min
# Frame 280/303 | 2.47 FPS | ETA: 0.2 min
# Frame 281/303 | 2.48 FPS | ETA: 0.1 min
# Frame 282/303 | 2.48 FPS | ETA: 0.1 min
# Frame 283/303 | 2.48 FPS | ETA: 0.1 min
# Frame 284/303 | 2.49 FPS | ETA: 0.1 min
# Frame 285/303 | 2.49 FPS | ETA: 0.1 min
# Frame 286/303 | 2.50 FPS | ETA: 0.1 min
# Frame 287/303 | 2.51 FPS | ETA: 0.1 min
# Frame 288/303 | 2.51 FPS | ETA: 0.1 min
# Frame 289/303 | 2.52 FPS | ETA: 0.1 min
# Frame 290/303 | 2.52 FPS | ETA: 0.1 min
# Frame 291/303 | 2.53 FPS | ETA: 0.1 min
# Frame 292/303 | 2.53 FPS | ETA: 0.1 min
# Frame 293/303 | 2.53 FPS | ETA: 0.1 min
# Frame 294/303 | 2.54 FPS | ETA: 0.1 min
# Frame 295/303 | 2.54 FPS | ETA: 0.1 min
# Frame 296/303 | 2.54 FPS | ETA: 0.0 min
# Frame 297/303 | 2.55 FPS | ETA: 0.0 min
# Frame 298/303 | 2.55 FPS | ETA: 0.0 min
# Frame 299/303 | 2.55 FPS | ETA: 0.0 min
# Frame 300/303 | 2.55 FPS | ETA: 0.0 min
# Frame 301/303 | 2.56 FPS | ETA: 0.0 min
# Frame 302/303 | 2.56 FPS | ETA: 0.0 min
# Frame 303/303 | 2.56 FPS | ETA: 0.0 min
# video saved to: D:\Aldi\stairvision\src\dataset\east\videos\output_videos\output_Copy of Copy of IMG_3086 (2).MOV

# %% [markdown]
# ### Below is the code to process video with mask output

# %%
import cv2
import numpy as np
from collections import deque
from ultralytics import YOLO
import os
import time

seg_model_path = "src/model/best_stair_handrail_model.pt"
pose_model_path = "src/model/best_pose_model.pt"
seg_model = YOLO(seg_model_path)
pose_model = YOLO(pose_model_path)

video_path = r"D:\Aldi\stairvision\src\dataset\west\videos\Copy of Copy of IMG_3093.MOV"
output_dir = r"D:\Aldi\stairvision\src\dataset\west\videos\output_videos"
output_prefix = "output_with_mask_"

os.makedirs(output_dir, exist_ok=True)

base_name = os.path.basename(video_path)
base_name_no_ext, ext = os.path.splitext(base_name)
new_file_name = f"{output_prefix}{base_name_no_ext}{ext}"
output_path = os.path.join(output_dir, new_file_name)
counter = 1
while os.path.exists(output_path):
    new_file_name = f"{output_prefix}{base_name_no_ext} ({counter}){ext}"
    output_path = os.path.join(output_dir, new_file_name)
    counter += 1

cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise RuntimeError(f"❌ cannot open video from the path: {video_path}")

total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

DILATE_KERNEL_SIZE = 4
CLOSE_KERNEL_SIZE = 4
ERODE_KERNEL_SIZE = 3
KP_CONF_THRESH = 0.25
HAND_RADIUS = max(5, int(0.05 * max(width, height)))
HAND_OVERLAP_RATIO = 0.2
SMOOTH_FRAMES = 3

# Keypoint connections for drawing the skeleton (COCO 17-point format)
SKELETON_CONNECTIONS = [
    (0, 1), (0, 2), (1, 3), (2, 4), (5, 6), (5, 7), (7, 9), (6, 8),
    (8, 10), (11, 12), (5, 11), (6, 12), (11, 13), (13, 15), (12, 14), (14, 16)
]

# Smoothing memory
hand_history = {}
status_memory = {}

start_time = time.time()
frame_num = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_orig = frame.copy()

    # stair handrail segmentation
    seg_results = seg_model.predict(frame, conf=0.4, verbose=False)
    handrail_mask = np.zeros((height, width), dtype=np.uint8)

    for r in seg_results:
        if r.masks is not None:
            for mask_poly, cls in zip(r.masks.xy, r.boxes.cls):
                if int(cls) == 0:
                    poly = np.array(mask_poly, dtype=np.int32)
                    cv2.fillPoly(handrail_mask, [poly], 255)

    # Morphological adjustments
    close_kernel = np.ones((CLOSE_KERNEL_SIZE, CLOSE_KERNEL_SIZE), np.uint8)
    dilate_kernel = np.ones((DILATE_KERNEL_SIZE, DILATE_KERNEL_SIZE), np.uint8)
    erode_kernel = np.ones((ERODE_KERNEL_SIZE, ERODE_KERNEL_SIZE), np.uint8)

    handrail_mask = cv2.morphologyEx(handrail_mask, cv2.MORPH_CLOSE, close_kernel)
    handrail_mask = cv2.dilate(handrail_mask, dilate_kernel, iterations=1)
    handrail_mask = cv2.erode(handrail_mask, erode_kernel, iterations=1)

    # person detection
    pose_results = pose_model.predict(frame_orig, conf=0.25, verbose=False)
    
    #  Visualization Setup
    frame_vis = frame.copy()
    
    # Create a semi-transparent overlay for the handrail mask
    mask_overlay = frame_vis.copy()
    mask_overlay[handrail_mask > 0] = (255, 255, 0)  # Cyan color for the mask
    frame_vis = cv2.addWeighted(mask_overlay, 0.4, frame_vis, 0.6, 0)

    for pid, r in enumerate(pose_results):
        if r.keypoints is None:
            continue

        kpts_xy = r.keypoints.xy.cpu().numpy()
        try:
            kpts_conf = r.keypoints.conf.cpu().numpy()
        except Exception:
            kpts_conf = np.ones((kpts_xy.shape[0], kpts_xy.shape[1]))

        for person_idx in range(kpts_xy.shape[0]):
            person_kpts = kpts_xy[person_idx]
            person_conf = kpts_conf[person_idx]

            # the Skeleton
            for i in range(person_kpts.shape[0]):
                if person_conf[i] > KP_CONF_THRESH:
                    x, y = int(person_kpts[i][0]), int(person_kpts[i][1])
                    cv2.circle(frame_vis, (x, y), 3, (200, 200, 200), -1)

            for start_idx, end_idx in SKELETON_CONNECTIONS:
                if person_kpts.shape[0] > max(start_idx, end_idx):
                    if person_conf[start_idx] > KP_CONF_THRESH and person_conf[end_idx] > KP_CONF_THRESH:
                        start_point = tuple(np.array(person_kpts[start_idx], int))
                        end_point = tuple(np.array(person_kpts[end_idx], int))
                        cv2.line(frame_vis, start_point, end_point, (255, 255, 255), 2)
            
            # Hand Holding Logic (with visualization on top of skeleton)
            holding_status_for_person = False
            for hid in [9, 10]:  # Left & right wrists
                if person_kpts.shape[0] <= hid or person_conf[hid] < KP_CONF_THRESH:
                    continue

                hx, hy = person_kpts[hid]

                # Position smoothing
                hand_history.setdefault((person_idx, hid), deque(maxlen=SMOOTH_FRAMES))
                hand_history[(person_idx, hid)].append((hx, hy))
                avg_hx = int(np.mean([p[0] for p in hand_history[(person_idx, hid)]]))
                avg_hy = int(np.mean([p[1] for p in hand_history[(person_idx, hid)]]))

                if not (0 <= avg_hx < width and 0 <= avg_hy < height):
                    continue

                # Overlap calculation
                y_grid, x_grid = np.ogrid[:height, :width]
                mask_circle = (x_grid - avg_hx) ** 2 + (y_grid - avg_hy) ** 2 <= HAND_RADIUS ** 2
                inside_mask = np.logical_and(mask_circle, handrail_mask > 0)
                overlap_ratio = inside_mask.sum() / (mask_circle.sum() + 1e-6)

                # Store status for smoothing
                status_memory.setdefault((person_idx, hid), deque(maxlen=SMOOTH_FRAMES))
                status_memory[(person_idx, hid)].append(overlap_ratio >= HAND_OVERLAP_RATIO)

                # Final decision for this hand
                is_hand_holding = sum(status_memory[(person_idx, hid)]) >= (SMOOTH_FRAMES // 2 + 1)
                
                # Update overall person status if at least one hand is holding
                if is_hand_holding:
                    holding_status_for_person = True

                # circle on wrist (green for holding, red for not)
                cv2.circle(frame_vis, (avg_hx, avg_hy), 8, (0, 255, 0) if is_hand_holding else (0, 0, 255), -1)

            # text label for the person
            label_pos = (int(person_kpts[5][0]), int(person_kpts[5][1]) - 20) if person_kpts.shape[0] > 5 else (10, 30)
            text = "HOLDING" if holding_status_for_person else "NOT HOLDING"
            color = (0, 255, 0) if holding_status_for_person else (0, 0, 255)
            cv2.putText(frame_vis, text, label_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    out.write(frame_vis)
    frame_num += 1

    elapsed = time.time() - start_time
    fps_proc = frame_num / elapsed if elapsed > 0 else 0
    eta = (total_frames - frame_num) / fps_proc if fps_proc > 0 else 0
    print(f"Frame {frame_num}/{total_frames} | {fps_proc:.2f} FPS | ETA: {eta/60:.1f} min", flush=True)

cap.release()
out.release()
print(f"video saved to: {output_path}")
# Out:
# Frame 1/863 | 0.59 FPS | ETA: 24.4 min
# Frame 2/863 | 1.03 FPS | ETA: 13.9 min
# Frame 3/863 | 1.35 FPS | ETA: 10.6 min
# Frame 4/863 | 1.66 FPS | ETA: 8.6 min
# Frame 5/863 | 1.91 FPS | ETA: 7.5 min
# Frame 6/863 | 2.12 FPS | ETA: 6.7 min
# Frame 7/863 | 2.32 FPS | ETA: 6.1 min
# Frame 8/863 | 2.46 FPS | ETA: 5.8 min
# Frame 9/863 | 2.59 FPS | ETA: 5.5 min
# Frame 10/863 | 2.71 FPS | ETA: 5.2 min
# Frame 11/863 | 2.79 FPS | ETA: 5.1 min
# Frame 12/863 | 2.86 FPS | ETA: 5.0 min
# Frame 13/863 | 2.90 FPS | ETA: 4.9 min
# Frame 14/863 | 2.93 FPS | ETA: 4.8 min
# Frame 15/863 | 2.96 FPS | ETA: 4.8 min
# Frame 16/863 | 2.99 FPS | ETA: 4.7 min
# Frame 17/863 | 3.03 FPS | ETA: 4.7 min
# Frame 18/863 | 3.06 FPS | ETA: 4.6 min
# Frame 19/863 | 3.08 FPS | ETA: 4.6 min
# Frame 20/863 | 3.11 FPS | ETA: 4.5 min
# Frame 21/863 | 3.15 FPS | ETA: 4.4 min
# Frame 22/863 | 3.18 FPS | ETA: 4.4 min
# Frame 23/863 | 3.21 FPS | ETA: 4.4 min
# Frame 24/863 | 3.23 FPS | ETA: 4.3 min
# Frame 25/863 | 3.26 FPS | ETA: 4.3 min
# Frame 26/863 | 3.27 FPS | ETA: 4.3 min
# Frame 27/863 | 3.29 FPS | ETA: 4.2 min
# Frame 28/863 | 3.31 FPS | ETA: 4.2 min
# Frame 29/863 | 3.33 FPS | ETA: 4.2 min
# Frame 30/863 | 3.35 FPS | ETA: 4.1 min
# Frame 31/863 | 3.37 FPS | ETA: 4.1 min
# Frame 32/863 | 3.38 FPS | ETA: 4.1 min
# Frame 33/863 | 3.40 FPS | ETA: 4.1 min
# Frame 34/863 | 3.41 FPS | ETA: 4.0 min
# Frame 35/863 | 3.43 FPS | ETA: 4.0 min
# Frame 36/863 | 3.44 FPS | ETA: 4.0 min
# Frame 37/863 | 3.46 FPS | ETA: 4.0 min
# Frame 38/863 | 3.46 FPS | ETA: 4.0 min
# Frame 39/863 | 3.47 FPS | ETA: 4.0 min
# Frame 40/863 | 3.48 FPS | ETA: 3.9 min
# Frame 41/863 | 3.50 FPS | ETA: 3.9 min
# Frame 42/863 | 3.50 FPS | ETA: 3.9 min
# Frame 43/863 | 3.52 FPS | ETA: 3.9 min
# Frame 44/863 | 3.53 FPS | ETA: 3.9 min
# Frame 45/863 | 3.54 FPS | ETA: 3.8 min
# Frame 46/863 | 3.55 FPS | ETA: 3.8 min
# Frame 47/863 | 3.57 FPS | ETA: 3.8 min
# Frame 48/863 | 3.57 FPS | ETA: 3.8 min
# Frame 49/863 | 3.58 FPS | ETA: 3.8 min
# Frame 50/863 | 3.58 FPS | ETA: 3.8 min
# Frame 51/863 | 3.59 FPS | ETA: 3.8 min
# Frame 52/863 | 3.60 FPS | ETA: 3.8 min
# Frame 53/863 | 3.60 FPS | ETA: 3.7 min
# Frame 54/863 | 3.61 FPS | ETA: 3.7 min
# Frame 55/863 | 3.61 FPS | ETA: 3.7 min
# Frame 56/863 | 3.61 FPS | ETA: 3.7 min
# Frame 57/863 | 3.62 FPS | ETA: 3.7 min
# Frame 58/863 | 3.62 FPS | ETA: 3.7 min
# Frame 59/863 | 3.62 FPS | ETA: 3.7 min
# Frame 60/863 | 3.61 FPS | ETA: 3.7 min
# Frame 61/863 | 3.60 FPS | ETA: 3.7 min
# Frame 62/863 | 3.60 FPS | ETA: 3.7 min
# Frame 63/863 | 3.59 FPS | ETA: 3.7 min
# Frame 64/863 | 3.57 FPS | ETA: 3.7 min
# Frame 65/863 | 3.56 FPS | ETA: 3.7 min
# Frame 66/863 | 3.54 FPS | ETA: 3.7 min
# Frame 67/863 | 3.54 FPS | ETA: 3.8 min
# Frame 68/863 | 3.52 FPS | ETA: 3.8 min
# Frame 69/863 | 3.51 FPS | ETA: 3.8 min
# Frame 70/863 | 3.50 FPS | ETA: 3.8 min
# Frame 71/863 | 3.50 FPS | ETA: 3.8 min
# Frame 72/863 | 3.49 FPS | ETA: 3.8 min
# Frame 73/863 | 3.49 FPS | ETA: 3.8 min
# Frame 74/863 | 3.48 FPS | ETA: 3.8 min
# Frame 75/863 | 3.48 FPS | ETA: 3.8 min
# Frame 76/863 | 3.48 FPS | ETA: 3.8 min
# Frame 77/863 | 3.48 FPS | ETA: 3.8 min
# Frame 78/863 | 3.48 FPS | ETA: 3.8 min
# Frame 79/863 | 3.48 FPS | ETA: 3.8 min
# Frame 80/863 | 3.48 FPS | ETA: 3.7 min
# Frame 81/863 | 3.48 FPS | ETA: 3.7 min
# Frame 82/863 | 3.48 FPS | ETA: 3.7 min
# Frame 83/863 | 3.47 FPS | ETA: 3.7 min
# Frame 84/863 | 3.47 FPS | ETA: 3.7 min
# Frame 85/863 | 3.47 FPS | ETA: 3.7 min
# Frame 86/863 | 3.47 FPS | ETA: 3.7 min
# Frame 87/863 | 3.47 FPS | ETA: 3.7 min
# Frame 88/863 | 3.46 FPS | ETA: 3.7 min
# Frame 89/863 | 3.46 FPS | ETA: 3.7 min
# Frame 90/863 | 3.47 FPS | ETA: 3.7 min
# Frame 91/863 | 3.46 FPS | ETA: 3.7 min
# Frame 92/863 | 3.46 FPS | ETA: 3.7 min
# Frame 93/863 | 3.46 FPS | ETA: 3.7 min
# Frame 94/863 | 3.46 FPS | ETA: 3.7 min
# Frame 95/863 | 3.46 FPS | ETA: 3.7 min
# Frame 96/863 | 3.45 FPS | ETA: 3.7 min
# Frame 97/863 | 3.45 FPS | ETA: 3.7 min
# Frame 98/863 | 3.45 FPS | ETA: 3.7 min
# Frame 99/863 | 3.45 FPS | ETA: 3.7 min
# Frame 100/863 | 3.45 FPS | ETA: 3.7 min
# Frame 101/863 | 3.45 FPS | ETA: 3.7 min
# Frame 102/863 | 3.45 FPS | ETA: 3.7 min
# Frame 103/863 | 3.45 FPS | ETA: 3.7 min
# Frame 104/863 | 3.44 FPS | ETA: 3.7 min
# Frame 105/863 | 3.45 FPS | ETA: 3.7 min
# Frame 106/863 | 3.44 FPS | ETA: 3.7 min
# Frame 107/863 | 3.44 FPS | ETA: 3.7 min
# Frame 108/863 | 3.44 FPS | ETA: 3.7 min
# Frame 109/863 | 3.44 FPS | ETA: 3.7 min
# Frame 110/863 | 3.43 FPS | ETA: 3.7 min
# Frame 111/863 | 3.43 FPS | ETA: 3.7 min
# Frame 112/863 | 3.43 FPS | ETA: 3.6 min
# Frame 113/863 | 3.43 FPS | ETA: 3.6 min
# Frame 114/863 | 3.42 FPS | ETA: 3.7 min
# Frame 115/863 | 3.42 FPS | ETA: 3.7 min
# Frame 116/863 | 3.41 FPS | ETA: 3.7 min
# Frame 117/863 | 3.41 FPS | ETA: 3.7 min
# Frame 118/863 | 3.40 FPS | ETA: 3.7 min
# Frame 119/863 | 3.39 FPS | ETA: 3.7 min
# Frame 120/863 | 3.39 FPS | ETA: 3.7 min
# Frame 121/863 | 3.38 FPS | ETA: 3.7 min
# Frame 122/863 | 3.38 FPS | ETA: 3.7 min
# Frame 123/863 | 3.37 FPS | ETA: 3.7 min
# Frame 124/863 | 3.36 FPS | ETA: 3.7 min
# Frame 125/863 | 3.36 FPS | ETA: 3.7 min
# Frame 126/863 | 3.35 FPS | ETA: 3.7 min
# Frame 127/863 | 3.35 FPS | ETA: 3.7 min
# Frame 128/863 | 3.35 FPS | ETA: 3.7 min
# Frame 129/863 | 3.34 FPS | ETA: 3.7 min
# Frame 130/863 | 3.33 FPS | ETA: 3.7 min
# Frame 131/863 | 3.31 FPS | ETA: 3.7 min
# Frame 132/863 | 3.31 FPS | ETA: 3.7 min
# Frame 133/863 | 3.30 FPS | ETA: 3.7 min
# Frame 134/863 | 3.29 FPS | ETA: 3.7 min
# Frame 135/863 | 3.28 FPS | ETA: 3.7 min
# Frame 136/863 | 3.27 FPS | ETA: 3.7 min
# Frame 137/863 | 3.25 FPS | ETA: 3.7 min
# Frame 138/863 | 3.24 FPS | ETA: 3.7 min
# Frame 139/863 | 3.23 FPS | ETA: 3.7 min
# Frame 140/863 | 3.22 FPS | ETA: 3.7 min
# Frame 141/863 | 3.21 FPS | ETA: 3.8 min
# Frame 142/863 | 3.20 FPS | ETA: 3.8 min
# Frame 143/863 | 3.19 FPS | ETA: 3.8 min
# Frame 144/863 | 3.18 FPS | ETA: 3.8 min
# Frame 145/863 | 3.17 FPS | ETA: 3.8 min
# Frame 146/863 | 3.16 FPS | ETA: 3.8 min
# Frame 147/863 | 3.15 FPS | ETA: 3.8 min
# Frame 148/863 | 3.15 FPS | ETA: 3.8 min
# Frame 149/863 | 3.14 FPS | ETA: 3.8 min
# Frame 150/863 | 3.14 FPS | ETA: 3.8 min
# Frame 151/863 | 3.14 FPS | ETA: 3.8 min
# Frame 152/863 | 3.13 FPS | ETA: 3.8 min
# Frame 153/863 | 3.13 FPS | ETA: 3.8 min
# Frame 154/863 | 3.12 FPS | ETA: 3.8 min
# Frame 155/863 | 3.12 FPS | ETA: 3.8 min
# Frame 156/863 | 3.11 FPS | ETA: 3.8 min
# Frame 157/863 | 3.10 FPS | ETA: 3.8 min
# Frame 158/863 | 3.09 FPS | ETA: 3.8 min
# Frame 159/863 | 3.09 FPS | ETA: 3.8 min
# Frame 160/863 | 3.09 FPS | ETA: 3.8 min
# Frame 161/863 | 3.09 FPS | ETA: 3.8 min
# Frame 162/863 | 3.09 FPS | ETA: 3.8 min
# Frame 163/863 | 3.09 FPS | ETA: 3.8 min
# Frame 164/863 | 3.08 FPS | ETA: 3.8 min
# Frame 165/863 | 3.08 FPS | ETA: 3.8 min
# Frame 166/863 | 3.08 FPS | ETA: 3.8 min
# Frame 167/863 | 3.07 FPS | ETA: 3.8 min
# Frame 168/863 | 3.06 FPS | ETA: 3.8 min
# Frame 169/863 | 3.06 FPS | ETA: 3.8 min
# Frame 170/863 | 3.05 FPS | ETA: 3.8 min
# Frame 171/863 | 3.04 FPS | ETA: 3.8 min
# Frame 172/863 | 3.04 FPS | ETA: 3.8 min
# Frame 173/863 | 3.03 FPS | ETA: 3.8 min
# Frame 174/863 | 3.02 FPS | ETA: 3.8 min
# Frame 175/863 | 3.01 FPS | ETA: 3.8 min
# Frame 176/863 | 3.01 FPS | ETA: 3.8 min
# Frame 177/863 | 3.01 FPS | ETA: 3.8 min
# Frame 178/863 | 3.01 FPS | ETA: 3.8 min
# Frame 179/863 | 3.01 FPS | ETA: 3.8 min
# Frame 180/863 | 3.01 FPS | ETA: 3.8 min
# Frame 181/863 | 3.00 FPS | ETA: 3.8 min
# Frame 182/863 | 3.00 FPS | ETA: 3.8 min
# Frame 183/863 | 3.00 FPS | ETA: 3.8 min
# Frame 184/863 | 3.00 FPS | ETA: 3.8 min
# Frame 185/863 | 3.00 FPS | ETA: 3.8 min
# Frame 186/863 | 3.00 FPS | ETA: 3.8 min
# Frame 187/863 | 3.00 FPS | ETA: 3.8 min
# Frame 188/863 | 2.99 FPS | ETA: 3.8 min
# Frame 189/863 | 2.99 FPS | ETA: 3.8 min
# Frame 190/863 | 2.99 FPS | ETA: 3.7 min
# Frame 191/863 | 2.99 FPS | ETA: 3.7 min
# Frame 192/863 | 2.99 FPS | ETA: 3.7 min
# Frame 193/863 | 2.99 FPS | ETA: 3.7 min
# Frame 194/863 | 2.99 FPS | ETA: 3.7 min
# Frame 195/863 | 2.99 FPS | ETA: 3.7 min
# Frame 196/863 | 2.99 FPS | ETA: 3.7 min
# Frame 197/863 | 2.99 FPS | ETA: 3.7 min
# Frame 198/863 | 2.99 FPS | ETA: 3.7 min
# Frame 199/863 | 2.99 FPS | ETA: 3.7 min
# Frame 200/863 | 2.99 FPS | ETA: 3.7 min
# Frame 201/863 | 2.99 FPS | ETA: 3.7 min
# Frame 202/863 | 2.98 FPS | ETA: 3.7 min
# Frame 203/863 | 2.98 FPS | ETA: 3.7 min
# Frame 204/863 | 2.97 FPS | ETA: 3.7 min
# Frame 205/863 | 2.97 FPS | ETA: 3.7 min
# Frame 206/863 | 2.96 FPS | ETA: 3.7 min
# Frame 207/863 | 2.96 FPS | ETA: 3.7 min
# Frame 208/863 | 2.95 FPS | ETA: 3.7 min
# Frame 209/863 | 2.95 FPS | ETA: 3.7 min
# Frame 210/863 | 2.95 FPS | ETA: 3.7 min
# Frame 211/863 | 2.95 FPS | ETA: 3.7 min
# Frame 212/863 | 2.95 FPS | ETA: 3.7 min
# Frame 213/863 | 2.95 FPS | ETA: 3.7 min
# Frame 214/863 | 2.95 FPS | ETA: 3.7 min
# Frame 215/863 | 2.95 FPS | ETA: 3.7 min
# Frame 216/863 | 2.95 FPS | ETA: 3.7 min
# Frame 217/863 | 2.95 FPS | ETA: 3.7 min
# Frame 218/863 | 2.94 FPS | ETA: 3.7 min
# Frame 219/863 | 2.94 FPS | ETA: 3.6 min
# Frame 220/863 | 2.94 FPS | ETA: 3.6 min
# Frame 221/863 | 2.94 FPS | ETA: 3.6 min
# Frame 222/863 | 2.93 FPS | ETA: 3.6 min
# Frame 223/863 | 2.93 FPS | ETA: 3.6 min
# Frame 224/863 | 2.93 FPS | ETA: 3.6 min
# Frame 225/863 | 2.92 FPS | ETA: 3.6 min
# Frame 226/863 | 2.92 FPS | ETA: 3.6 min
# Frame 227/863 | 2.92 FPS | ETA: 3.6 min
# Frame 228/863 | 2.92 FPS | ETA: 3.6 min
# Frame 229/863 | 2.92 FPS | ETA: 3.6 min
# Frame 230/863 | 2.91 FPS | ETA: 3.6 min
# Frame 231/863 | 2.91 FPS | ETA: 3.6 min
# Frame 232/863 | 2.91 FPS | ETA: 3.6 min
# Frame 233/863 | 2.91 FPS | ETA: 3.6 min
# Frame 234/863 | 2.90 FPS | ETA: 3.6 min
# Frame 235/863 | 2.90 FPS | ETA: 3.6 min
# Frame 236/863 | 2.89 FPS | ETA: 3.6 min
# Frame 237/863 | 2.89 FPS | ETA: 3.6 min
# Frame 238/863 | 2.88 FPS | ETA: 3.6 min
# Frame 239/863 | 2.88 FPS | ETA: 3.6 min
# Frame 240/863 | 2.88 FPS | ETA: 3.6 min
# Frame 241/863 | 2.87 FPS | ETA: 3.6 min
# Frame 242/863 | 2.87 FPS | ETA: 3.6 min
# Frame 243/863 | 2.87 FPS | ETA: 3.6 min
# Frame 244/863 | 2.86 FPS | ETA: 3.6 min
# Frame 245/863 | 2.86 FPS | ETA: 3.6 min
# Frame 246/863 | 2.86 FPS | ETA: 3.6 min
# Frame 247/863 | 2.86 FPS | ETA: 3.6 min
# Frame 248/863 | 2.85 FPS | ETA: 3.6 min
# Frame 249/863 | 2.85 FPS | ETA: 3.6 min
# Frame 250/863 | 2.85 FPS | ETA: 3.6 min
# Frame 251/863 | 2.84 FPS | ETA: 3.6 min
# Frame 252/863 | 2.84 FPS | ETA: 3.6 min
# Frame 253/863 | 2.84 FPS | ETA: 3.6 min
# Frame 254/863 | 2.84 FPS | ETA: 3.6 min
# Frame 255/863 | 2.84 FPS | ETA: 3.6 min
# Frame 256/863 | 2.84 FPS | ETA: 3.6 min
# Frame 257/863 | 2.84 FPS | ETA: 3.6 min
# Frame 258/863 | 2.84 FPS | ETA: 3.5 min
# Frame 259/863 | 2.84 FPS | ETA: 3.5 min
# Frame 260/863 | 2.84 FPS | ETA: 3.5 min
# Frame 261/863 | 2.84 FPS | ETA: 3.5 min
# Frame 262/863 | 2.84 FPS | ETA: 3.5 min
# Frame 263/863 | 2.84 FPS | ETA: 3.5 min
# Frame 264/863 | 2.84 FPS | ETA: 3.5 min
# Frame 265/863 | 2.84 FPS | ETA: 3.5 min
# Frame 266/863 | 2.84 FPS | ETA: 3.5 min
# Frame 267/863 | 2.84 FPS | ETA: 3.5 min
# Frame 268/863 | 2.84 FPS | ETA: 3.5 min
# Frame 269/863 | 2.84 FPS | ETA: 3.5 min
# Frame 270/863 | 2.84 FPS | ETA: 3.5 min
# Frame 271/863 | 2.84 FPS | ETA: 3.5 min
# Frame 272/863 | 2.83 FPS | ETA: 3.5 min
# Frame 273/863 | 2.83 FPS | ETA: 3.5 min
# Frame 274/863 | 2.83 FPS | ETA: 3.5 min
# Frame 275/863 | 2.83 FPS | ETA: 3.5 min
# Frame 276/863 | 2.83 FPS | ETA: 3.5 min
# Frame 277/863 | 2.83 FPS | ETA: 3.5 min
# Frame 278/863 | 2.83 FPS | ETA: 3.4 min
# Frame 279/863 | 2.83 FPS | ETA: 3.4 min
# Frame 280/863 | 2.83 FPS | ETA: 3.4 min
# Frame 281/863 | 2.83 FPS | ETA: 3.4 min
# Frame 282/863 | 2.84 FPS | ETA: 3.4 min
# Frame 283/863 | 2.84 FPS | ETA: 3.4 min
# Frame 284/863 | 2.84 FPS | ETA: 3.4 min
# Frame 285/863 | 2.83 FPS | ETA: 3.4 min
# Frame 286/863 | 2.83 FPS | ETA: 3.4 min
# Frame 287/863 | 2.83 FPS | ETA: 3.4 min
# Frame 288/863 | 2.83 FPS | ETA: 3.4 min
# Frame 289/863 | 2.82 FPS | ETA: 3.4 min
# Frame 290/863 | 2.82 FPS | ETA: 3.4 min
# Frame 291/863 | 2.82 FPS | ETA: 3.4 min
# Frame 292/863 | 2.82 FPS | ETA: 3.4 min
# Frame 293/863 | 2.82 FPS | ETA: 3.4 min
# Frame 294/863 | 2.81 FPS | ETA: 3.4 min
# Frame 295/863 | 2.81 FPS | ETA: 3.4 min
# Frame 296/863 | 2.81 FPS | ETA: 3.4 min
# Frame 297/863 | 2.81 FPS | ETA: 3.4 min
# Frame 298/863 | 2.81 FPS | ETA: 3.4 min
# Frame 299/863 | 2.81 FPS | ETA: 3.3 min
# Frame 300/863 | 2.81 FPS | ETA: 3.3 min
# Frame 301/863 | 2.81 FPS | ETA: 3.3 min
# Frame 302/863 | 2.81 FPS | ETA: 3.3 min
# Frame 303/863 | 2.81 FPS | ETA: 3.3 min
# Frame 304/863 | 2.81 FPS | ETA: 3.3 min
# Frame 305/863 | 2.81 FPS | ETA: 3.3 min
# Frame 306/863 | 2.81 FPS | ETA: 3.3 min
# Frame 307/863 | 2.81 FPS | ETA: 3.3 min
# Frame 308/863 | 2.81 FPS | ETA: 3.3 min
# Frame 309/863 | 2.80 FPS | ETA: 3.3 min
# Frame 310/863 | 2.80 FPS | ETA: 3.3 min
# Frame 311/863 | 2.80 FPS | ETA: 3.3 min
# Frame 312/863 | 2.80 FPS | ETA: 3.3 min
# Frame 313/863 | 2.80 FPS | ETA: 3.3 min
# Frame 314/863 | 2.79 FPS | ETA: 3.3 min
# Frame 315/863 | 2.79 FPS | ETA: 3.3 min
# Frame 316/863 | 2.79 FPS | ETA: 3.3 min
# Frame 317/863 | 2.79 FPS | ETA: 3.3 min
# Frame 318/863 | 2.79 FPS | ETA: 3.3 min
# Frame 319/863 | 2.79 FPS | ETA: 3.3 min
# Frame 320/863 | 2.78 FPS | ETA: 3.3 min
# Frame 321/863 | 2.78 FPS | ETA: 3.2 min
# Frame 322/863 | 2.78 FPS | ETA: 3.2 min
# Frame 323/863 | 2.78 FPS | ETA: 3.2 min
# Frame 324/863 | 2.78 FPS | ETA: 3.2 min
# Frame 325/863 | 2.78 FPS | ETA: 3.2 min
# Frame 326/863 | 2.78 FPS | ETA: 3.2 min
# Frame 327/863 | 2.78 FPS | ETA: 3.2 min
# Frame 328/863 | 2.78 FPS | ETA: 3.2 min
# Frame 329/863 | 2.78 FPS | ETA: 3.2 min
# Frame 330/863 | 2.77 FPS | ETA: 3.2 min
# Frame 331/863 | 2.77 FPS | ETA: 3.2 min
# Frame 332/863 | 2.77 FPS | ETA: 3.2 min
# Frame 333/863 | 2.77 FPS | ETA: 3.2 min
# Frame 334/863 | 2.77 FPS | ETA: 3.2 min
# Frame 335/863 | 2.76 FPS | ETA: 3.2 min
# Frame 336/863 | 2.76 FPS | ETA: 3.2 min
# Frame 337/863 | 2.76 FPS | ETA: 3.2 min
# Frame 338/863 | 2.76 FPS | ETA: 3.2 min
# Frame 339/863 | 2.76 FPS | ETA: 3.2 min
# Frame 340/863 | 2.76 FPS | ETA: 3.2 min
# Frame 341/863 | 2.76 FPS | ETA: 3.2 min
# Frame 342/863 | 2.75 FPS | ETA: 3.2 min
# Frame 343/863 | 2.75 FPS | ETA: 3.1 min
# Frame 344/863 | 2.75 FPS | ETA: 3.1 min
# Frame 345/863 | 2.75 FPS | ETA: 3.1 min
# Frame 346/863 | 2.75 FPS | ETA: 3.1 min
# Frame 347/863 | 2.75 FPS | ETA: 3.1 min
# Frame 348/863 | 2.75 FPS | ETA: 3.1 min
# Frame 349/863 | 2.74 FPS | ETA: 3.1 min
# Frame 350/863 | 2.74 FPS | ETA: 3.1 min
# Frame 351/863 | 2.74 FPS | ETA: 3.1 min
# Frame 352/863 | 2.74 FPS | ETA: 3.1 min
# Frame 353/863 | 2.74 FPS | ETA: 3.1 min
# Frame 354/863 | 2.74 FPS | ETA: 3.1 min
# Frame 355/863 | 2.74 FPS | ETA: 3.1 min
# Frame 356/863 | 2.73 FPS | ETA: 3.1 min
# Frame 357/863 | 2.73 FPS | ETA: 3.1 min
# Frame 358/863 | 2.73 FPS | ETA: 3.1 min
# Frame 359/863 | 2.73 FPS | ETA: 3.1 min
# Frame 360/863 | 2.73 FPS | ETA: 3.1 min
# Frame 361/863 | 2.73 FPS | ETA: 3.1 min
# Frame 362/863 | 2.72 FPS | ETA: 3.1 min
# Frame 363/863 | 2.72 FPS | ETA: 3.1 min
# Frame 364/863 | 2.72 FPS | ETA: 3.1 min
# Frame 365/863 | 2.72 FPS | ETA: 3.1 min
# Frame 366/863 | 2.72 FPS | ETA: 3.0 min
# Frame 367/863 | 2.72 FPS | ETA: 3.0 min
# Frame 368/863 | 2.72 FPS | ETA: 3.0 min
# Frame 369/863 | 2.72 FPS | ETA: 3.0 min
# Frame 370/863 | 2.71 FPS | ETA: 3.0 min
# Frame 371/863 | 2.71 FPS | ETA: 3.0 min
# Frame 372/863 | 2.71 FPS | ETA: 3.0 min
# Frame 373/863 | 2.71 FPS | ETA: 3.0 min
# Frame 374/863 | 2.71 FPS | ETA: 3.0 min
# Frame 375/863 | 2.71 FPS | ETA: 3.0 min
# Frame 376/863 | 2.71 FPS | ETA: 3.0 min
# Frame 377/863 | 2.71 FPS | ETA: 3.0 min
# Frame 378/863 | 2.70 FPS | ETA: 3.0 min
# Frame 379/863 | 2.70 FPS | ETA: 3.0 min
# Frame 380/863 | 2.70 FPS | ETA: 3.0 min
# Frame 381/863 | 2.70 FPS | ETA: 3.0 min
# Frame 382/863 | 2.70 FPS | ETA: 3.0 min
# Frame 383/863 | 2.70 FPS | ETA: 3.0 min
# Frame 384/863 | 2.70 FPS | ETA: 3.0 min
# Frame 385/863 | 2.70 FPS | ETA: 3.0 min
# Frame 386/863 | 2.69 FPS | ETA: 3.0 min
# Frame 387/863 | 2.69 FPS | ETA: 2.9 min
# Frame 388/863 | 2.69 FPS | ETA: 2.9 min
# Frame 389/863 | 2.69 FPS | ETA: 2.9 min
# Frame 390/863 | 2.69 FPS | ETA: 2.9 min
# Frame 391/863 | 2.69 FPS | ETA: 2.9 min
# Frame 392/863 | 2.69 FPS | ETA: 2.9 min
# Frame 393/863 | 2.68 FPS | ETA: 2.9 min
# Frame 394/863 | 2.68 FPS | ETA: 2.9 min
# Frame 395/863 | 2.68 FPS | ETA: 2.9 min
# Frame 396/863 | 2.68 FPS | ETA: 2.9 min
# Frame 397/863 | 2.68 FPS | ETA: 2.9 min
# Frame 398/863 | 2.68 FPS | ETA: 2.9 min
# Frame 399/863 | 2.68 FPS | ETA: 2.9 min
# Frame 400/863 | 2.68 FPS | ETA: 2.9 min
# Frame 401/863 | 2.68 FPS | ETA: 2.9 min
# Frame 402/863 | 2.68 FPS | ETA: 2.9 min
# Frame 403/863 | 2.67 FPS | ETA: 2.9 min
# Frame 404/863 | 2.67 FPS | ETA: 2.9 min
# Frame 405/863 | 2.67 FPS | ETA: 2.9 min
# Frame 406/863 | 2.67 FPS | ETA: 2.9 min
# Frame 407/863 | 2.67 FPS | ETA: 2.8 min
# Frame 408/863 | 2.67 FPS | ETA: 2.8 min
# Frame 409/863 | 2.67 FPS | ETA: 2.8 min
# Frame 410/863 | 2.67 FPS | ETA: 2.8 min
# Frame 411/863 | 2.66 FPS | ETA: 2.8 min
# Frame 412/863 | 2.66 FPS | ETA: 2.8 min
# Frame 413/863 | 2.66 FPS | ETA: 2.8 min
# Frame 414/863 | 2.66 FPS | ETA: 2.8 min
# Frame 415/863 | 2.66 FPS | ETA: 2.8 min
# Frame 416/863 | 2.66 FPS | ETA: 2.8 min
# Frame 417/863 | 2.66 FPS | ETA: 2.8 min
# Frame 418/863 | 2.66 FPS | ETA: 2.8 min
# Frame 419/863 | 2.66 FPS | ETA: 2.8 min
# Frame 420/863 | 2.66 FPS | ETA: 2.8 min
# Frame 421/863 | 2.65 FPS | ETA: 2.8 min
# Frame 422/863 | 2.65 FPS | ETA: 2.8 min
# Frame 423/863 | 2.65 FPS | ETA: 2.8 min
# Frame 424/863 | 2.65 FPS | ETA: 2.8 min
# Frame 425/863 | 2.65 FPS | ETA: 2.8 min
# Frame 426/863 | 2.65 FPS | ETA: 2.7 min
# Frame 427/863 | 2.65 FPS | ETA: 2.7 min
# Frame 428/863 | 2.65 FPS | ETA: 2.7 min
# Frame 429/863 | 2.65 FPS | ETA: 2.7 min
# Frame 430/863 | 2.65 FPS | ETA: 2.7 min
# Frame 431/863 | 2.65 FPS | ETA: 2.7 min
# Frame 432/863 | 2.64 FPS | ETA: 2.7 min
# Frame 433/863 | 2.64 FPS | ETA: 2.7 min
# Frame 434/863 | 2.64 FPS | ETA: 2.7 min
# Frame 435/863 | 2.64 FPS | ETA: 2.7 min
# Frame 436/863 | 2.64 FPS | ETA: 2.7 min
# Frame 437/863 | 2.64 FPS | ETA: 2.7 min
# Frame 438/863 | 2.64 FPS | ETA: 2.7 min
# Frame 439/863 | 2.64 FPS | ETA: 2.7 min
# Frame 440/863 | 2.64 FPS | ETA: 2.7 min
# Frame 441/863 | 2.64 FPS | ETA: 2.7 min
# Frame 442/863 | 2.64 FPS | ETA: 2.7 min
# Frame 443/863 | 2.63 FPS | ETA: 2.7 min
# Frame 444/863 | 2.63 FPS | ETA: 2.7 min
# Frame 445/863 | 2.63 FPS | ETA: 2.6 min
# Frame 446/863 | 2.63 FPS | ETA: 2.6 min
# Frame 447/863 | 2.63 FPS | ETA: 2.6 min
# Frame 448/863 | 2.63 FPS | ETA: 2.6 min
# Frame 449/863 | 2.63 FPS | ETA: 2.6 min
# Frame 450/863 | 2.63 FPS | ETA: 2.6 min
# Frame 451/863 | 2.63 FPS | ETA: 2.6 min
# Frame 452/863 | 2.63 FPS | ETA: 2.6 min
# Frame 453/863 | 2.63 FPS | ETA: 2.6 min
# Frame 454/863 | 2.63 FPS | ETA: 2.6 min
# Frame 455/863 | 2.62 FPS | ETA: 2.6 min
# Frame 456/863 | 2.62 FPS | ETA: 2.6 min
# Frame 457/863 | 2.62 FPS | ETA: 2.6 min
# Frame 458/863 | 2.62 FPS | ETA: 2.6 min
# Frame 459/863 | 2.62 FPS | ETA: 2.6 min
# Frame 460/863 | 2.62 FPS | ETA: 2.6 min
# Frame 461/863 | 2.62 FPS | ETA: 2.6 min
# Frame 462/863 | 2.62 FPS | ETA: 2.6 min
# Frame 463/863 | 2.62 FPS | ETA: 2.5 min
# Frame 464/863 | 2.62 FPS | ETA: 2.5 min
# Frame 465/863 | 2.62 FPS | ETA: 2.5 min
# Frame 466/863 | 2.62 FPS | ETA: 2.5 min
# Frame 467/863 | 2.61 FPS | ETA: 2.5 min
# Frame 468/863 | 2.61 FPS | ETA: 2.5 min
# Frame 469/863 | 2.61 FPS | ETA: 2.5 min
# Frame 470/863 | 2.61 FPS | ETA: 2.5 min
# Frame 471/863 | 2.61 FPS | ETA: 2.5 min
# Frame 472/863 | 2.61 FPS | ETA: 2.5 min
# Frame 473/863 | 2.61 FPS | ETA: 2.5 min
# Frame 474/863 | 2.61 FPS | ETA: 2.5 min
# Frame 475/863 | 2.61 FPS | ETA: 2.5 min
# Frame 476/863 | 2.61 FPS | ETA: 2.5 min
# Frame 477/863 | 2.61 FPS | ETA: 2.5 min
# Frame 478/863 | 2.60 FPS | ETA: 2.5 min
# Frame 479/863 | 2.60 FPS | ETA: 2.5 min
# Frame 480/863 | 2.60 FPS | ETA: 2.5 min
# Frame 481/863 | 2.60 FPS | ETA: 2.4 min
# Frame 482/863 | 2.60 FPS | ETA: 2.4 min
# Frame 483/863 | 2.60 FPS | ETA: 2.4 min
# Frame 484/863 | 2.60 FPS | ETA: 2.4 min
# Frame 485/863 | 2.60 FPS | ETA: 2.4 min
# Frame 486/863 | 2.60 FPS | ETA: 2.4 min
# Frame 487/863 | 2.60 FPS | ETA: 2.4 min
# Frame 488/863 | 2.60 FPS | ETA: 2.4 min
# Frame 489/863 | 2.60 FPS | ETA: 2.4 min
# Frame 490/863 | 2.60 FPS | ETA: 2.4 min
# Frame 491/863 | 2.60 FPS | ETA: 2.4 min
# Frame 492/863 | 2.60 FPS | ETA: 2.4 min
# Frame 493/863 | 2.59 FPS | ETA: 2.4 min
# Frame 494/863 | 2.59 FPS | ETA: 2.4 min
# Frame 495/863 | 2.59 FPS | ETA: 2.4 min
# Frame 496/863 | 2.59 FPS | ETA: 2.4 min
# Frame 497/863 | 2.59 FPS | ETA: 2.4 min
# Frame 498/863 | 2.59 FPS | ETA: 2.3 min
# Frame 499/863 | 2.59 FPS | ETA: 2.3 min
# Frame 500/863 | 2.59 FPS | ETA: 2.3 min
# Frame 501/863 | 2.59 FPS | ETA: 2.3 min
# Frame 502/863 | 2.59 FPS | ETA: 2.3 min
# Frame 503/863 | 2.59 FPS | ETA: 2.3 min
# Frame 504/863 | 2.59 FPS | ETA: 2.3 min
# Frame 505/863 | 2.59 FPS | ETA: 2.3 min
# Frame 506/863 | 2.59 FPS | ETA: 2.3 min
# Frame 507/863 | 2.59 FPS | ETA: 2.3 min
# Frame 508/863 | 2.59 FPS | ETA: 2.3 min
# Frame 509/863 | 2.58 FPS | ETA: 2.3 min
# Frame 510/863 | 2.58 FPS | ETA: 2.3 min
# Frame 511/863 | 2.58 FPS | ETA: 2.3 min
# Frame 512/863 | 2.58 FPS | ETA: 2.3 min
# Frame 513/863 | 2.58 FPS | ETA: 2.3 min
# Frame 514/863 | 2.58 FPS | ETA: 2.3 min
# Frame 515/863 | 2.58 FPS | ETA: 2.2 min
# Frame 516/863 | 2.58 FPS | ETA: 2.2 min
# Frame 517/863 | 2.58 FPS | ETA: 2.2 min
# Frame 518/863 | 2.58 FPS | ETA: 2.2 min
# Frame 519/863 | 2.58 FPS | ETA: 2.2 min
# Frame 520/863 | 2.58 FPS | ETA: 2.2 min
# Frame 521/863 | 2.58 FPS | ETA: 2.2 min
# Frame 522/863 | 2.58 FPS | ETA: 2.2 min
# Frame 523/863 | 2.58 FPS | ETA: 2.2 min
# Frame 524/863 | 2.58 FPS | ETA: 2.2 min
# Frame 525/863 | 2.58 FPS | ETA: 2.2 min
# Frame 526/863 | 2.57 FPS | ETA: 2.2 min
# Frame 527/863 | 2.57 FPS | ETA: 2.2 min
# Frame 528/863 | 2.57 FPS | ETA: 2.2 min
# Frame 529/863 | 2.57 FPS | ETA: 2.2 min
# Frame 530/863 | 2.57 FPS | ETA: 2.2 min
# Frame 531/863 | 2.57 FPS | ETA: 2.2 min
# Frame 532/863 | 2.57 FPS | ETA: 2.1 min
# Frame 533/863 | 2.57 FPS | ETA: 2.1 min
# Frame 534/863 | 2.57 FPS | ETA: 2.1 min
# Frame 535/863 | 2.57 FPS | ETA: 2.1 min
# Frame 536/863 | 2.57 FPS | ETA: 2.1 min
# Frame 537/863 | 2.57 FPS | ETA: 2.1 min
# Frame 538/863 | 2.57 FPS | ETA: 2.1 min
# Frame 539/863 | 2.57 FPS | ETA: 2.1 min
# Frame 540/863 | 2.57 FPS | ETA: 2.1 min
# Frame 541/863 | 2.57 FPS | ETA: 2.1 min
# Frame 542/863 | 2.56 FPS | ETA: 2.1 min
# Frame 543/863 | 2.56 FPS | ETA: 2.1 min
# Frame 544/863 | 2.56 FPS | ETA: 2.1 min
# Frame 545/863 | 2.56 FPS | ETA: 2.1 min
# Frame 546/863 | 2.56 FPS | ETA: 2.1 min
# Frame 547/863 | 2.56 FPS | ETA: 2.1 min
# Frame 548/863 | 2.56 FPS | ETA: 2.1 min
# Frame 549/863 | 2.56 FPS | ETA: 2.0 min
# Frame 550/863 | 2.56 FPS | ETA: 2.0 min
# Frame 551/863 | 2.56 FPS | ETA: 2.0 min
# Frame 552/863 | 2.56 FPS | ETA: 2.0 min
# Frame 553/863 | 2.56 FPS | ETA: 2.0 min
# Frame 554/863 | 2.56 FPS | ETA: 2.0 min
# Frame 555/863 | 2.56 FPS | ETA: 2.0 min
# Frame 556/863 | 2.56 FPS | ETA: 2.0 min
# Frame 557/863 | 2.56 FPS | ETA: 2.0 min
# Frame 558/863 | 2.55 FPS | ETA: 2.0 min
# Frame 559/863 | 2.55 FPS | ETA: 2.0 min
# Frame 560/863 | 2.55 FPS | ETA: 2.0 min
# Frame 561/863 | 2.55 FPS | ETA: 2.0 min
# Frame 562/863 | 2.55 FPS | ETA: 2.0 min
# Frame 563/863 | 2.55 FPS | ETA: 2.0 min
# Frame 564/863 | 2.55 FPS | ETA: 2.0 min
# Frame 565/863 | 2.55 FPS | ETA: 1.9 min
# Frame 566/863 | 2.55 FPS | ETA: 1.9 min
# Frame 567/863 | 2.55 FPS | ETA: 1.9 min
# Frame 568/863 | 2.55 FPS | ETA: 1.9 min
# Frame 569/863 | 2.55 FPS | ETA: 1.9 min
# Frame 570/863 | 2.55 FPS | ETA: 1.9 min
# Frame 571/863 | 2.55 FPS | ETA: 1.9 min
# Frame 572/863 | 2.55 FPS | ETA: 1.9 min
# Frame 573/863 | 2.55 FPS | ETA: 1.9 min
# Frame 574/863 | 2.55 FPS | ETA: 1.9 min
# Frame 575/863 | 2.55 FPS | ETA: 1.9 min
# Frame 576/863 | 2.55 FPS | ETA: 1.9 min
# Frame 577/863 | 2.55 FPS | ETA: 1.9 min
# Frame 578/863 | 2.55 FPS | ETA: 1.9 min
# Frame 579/863 | 2.55 FPS | ETA: 1.9 min
# Frame 580/863 | 2.55 FPS | ETA: 1.9 min
# Frame 581/863 | 2.54 FPS | ETA: 1.8 min
# Frame 582/863 | 2.54 FPS | ETA: 1.8 min
# Frame 583/863 | 2.54 FPS | ETA: 1.8 min
# Frame 584/863 | 2.54 FPS | ETA: 1.8 min
# Frame 585/863 | 2.54 FPS | ETA: 1.8 min
# Frame 586/863 | 2.54 FPS | ETA: 1.8 min
# Frame 587/863 | 2.54 FPS | ETA: 1.8 min
# Frame 588/863 | 2.54 FPS | ETA: 1.8 min
# Frame 589/863 | 2.54 FPS | ETA: 1.8 min
# Frame 590/863 | 2.54 FPS | ETA: 1.8 min
# Frame 591/863 | 2.54 FPS | ETA: 1.8 min
# Frame 592/863 | 2.54 FPS | ETA: 1.8 min
# Frame 593/863 | 2.54 FPS | ETA: 1.8 min
# Frame 594/863 | 2.54 FPS | ETA: 1.8 min
# Frame 595/863 | 2.54 FPS | ETA: 1.8 min
# Frame 596/863 | 2.54 FPS | ETA: 1.8 min
# Frame 597/863 | 2.54 FPS | ETA: 1.7 min
# Frame 598/863 | 2.54 FPS | ETA: 1.7 min
# Frame 599/863 | 2.54 FPS | ETA: 1.7 min
# Frame 600/863 | 2.54 FPS | ETA: 1.7 min
# Frame 601/863 | 2.54 FPS | ETA: 1.7 min
# Frame 602/863 | 2.54 FPS | ETA: 1.7 min
# Frame 603/863 | 2.53 FPS | ETA: 1.7 min
# Frame 604/863 | 2.53 FPS | ETA: 1.7 min
# Frame 605/863 | 2.53 FPS | ETA: 1.7 min
# Frame 606/863 | 2.53 FPS | ETA: 1.7 min
# Frame 607/863 | 2.53 FPS | ETA: 1.7 min
# Frame 608/863 | 2.53 FPS | ETA: 1.7 min
# Frame 609/863 | 2.53 FPS | ETA: 1.7 min
# Frame 610/863 | 2.53 FPS | ETA: 1.7 min
# Frame 611/863 | 2.53 FPS | ETA: 1.7 min
# Frame 612/863 | 2.53 FPS | ETA: 1.7 min
# Frame 613/863 | 2.53 FPS | ETA: 1.6 min
# Frame 614/863 | 2.53 FPS | ETA: 1.6 min
# Frame 615/863 | 2.53 FPS | ETA: 1.6 min
# Frame 616/863 | 2.53 FPS | ETA: 1.6 min
# Frame 617/863 | 2.53 FPS | ETA: 1.6 min
# Frame 618/863 | 2.53 FPS | ETA: 1.6 min
# Frame 619/863 | 2.53 FPS | ETA: 1.6 min
# Frame 620/863 | 2.53 FPS | ETA: 1.6 min
# Frame 621/863 | 2.53 FPS | ETA: 1.6 min
# Frame 622/863 | 2.53 FPS | ETA: 1.6 min
# Frame 623/863 | 2.53 FPS | ETA: 1.6 min
# Frame 624/863 | 2.53 FPS | ETA: 1.6 min
# Frame 625/863 | 2.53 FPS | ETA: 1.6 min
# Frame 626/863 | 2.52 FPS | ETA: 1.6 min
# Frame 627/863 | 2.52 FPS | ETA: 1.6 min
# Frame 628/863 | 2.52 FPS | ETA: 1.6 min
# Frame 629/863 | 2.52 FPS | ETA: 1.5 min
# Frame 630/863 | 2.52 FPS | ETA: 1.5 min
# Frame 631/863 | 2.52 FPS | ETA: 1.5 min
# Frame 632/863 | 2.52 FPS | ETA: 1.5 min
# Frame 633/863 | 2.52 FPS | ETA: 1.5 min
# Frame 634/863 | 2.52 FPS | ETA: 1.5 min
# Frame 635/863 | 2.52 FPS | ETA: 1.5 min
# Frame 636/863 | 2.52 FPS | ETA: 1.5 min
# Frame 637/863 | 2.52 FPS | ETA: 1.5 min
# Frame 638/863 | 2.52 FPS | ETA: 1.5 min
# Frame 639/863 | 2.52 FPS | ETA: 1.5 min
# Frame 640/863 | 2.52 FPS | ETA: 1.5 min
# Frame 641/863 | 2.52 FPS | ETA: 1.5 min
# Frame 642/863 | 2.52 FPS | ETA: 1.5 min
# Frame 643/863 | 2.52 FPS | ETA: 1.5 min
# Frame 644/863 | 2.52 FPS | ETA: 1.4 min
# Frame 645/863 | 2.52 FPS | ETA: 1.4 min
# Frame 646/863 | 2.52 FPS | ETA: 1.4 min
# Frame 647/863 | 2.52 FPS | ETA: 1.4 min
# Frame 648/863 | 2.52 FPS | ETA: 1.4 min
# Frame 649/863 | 2.52 FPS | ETA: 1.4 min
# Frame 650/863 | 2.52 FPS | ETA: 1.4 min
# Frame 651/863 | 2.52 FPS | ETA: 1.4 min
# Frame 652/863 | 2.52 FPS | ETA: 1.4 min
# Frame 653/863 | 2.51 FPS | ETA: 1.4 min
# Frame 654/863 | 2.51 FPS | ETA: 1.4 min
# Frame 655/863 | 2.51 FPS | ETA: 1.4 min
# Frame 656/863 | 2.51 FPS | ETA: 1.4 min
# Frame 657/863 | 2.51 FPS | ETA: 1.4 min
# Frame 658/863 | 2.51 FPS | ETA: 1.4 min
# Frame 659/863 | 2.51 FPS | ETA: 1.4 min
# Frame 660/863 | 2.51 FPS | ETA: 1.3 min
# Frame 661/863 | 2.51 FPS | ETA: 1.3 min
# Frame 662/863 | 2.51 FPS | ETA: 1.3 min
# Frame 663/863 | 2.51 FPS | ETA: 1.3 min
# Frame 664/863 | 2.51 FPS | ETA: 1.3 min
# Frame 665/863 | 2.51 FPS | ETA: 1.3 min
# Frame 666/863 | 2.51 FPS | ETA: 1.3 min
# Frame 667/863 | 2.51 FPS | ETA: 1.3 min
# Frame 668/863 | 2.51 FPS | ETA: 1.3 min
# Frame 669/863 | 2.51 FPS | ETA: 1.3 min
# Frame 670/863 | 2.51 FPS | ETA: 1.3 min
# Frame 671/863 | 2.51 FPS | ETA: 1.3 min
# Frame 672/863 | 2.51 FPS | ETA: 1.3 min
# Frame 673/863 | 2.51 FPS | ETA: 1.3 min
# Frame 674/863 | 2.51 FPS | ETA: 1.3 min
# Frame 675/863 | 2.51 FPS | ETA: 1.2 min
# Frame 676/863 | 2.51 FPS | ETA: 1.2 min
# Frame 677/863 | 2.51 FPS | ETA: 1.2 min
# Frame 678/863 | 2.51 FPS | ETA: 1.2 min
# Frame 679/863 | 2.51 FPS | ETA: 1.2 min
# Frame 680/863 | 2.51 FPS | ETA: 1.2 min
# Frame 681/863 | 2.50 FPS | ETA: 1.2 min
# Frame 682/863 | 2.50 FPS | ETA: 1.2 min
# Frame 683/863 | 2.50 FPS | ETA: 1.2 min
# Frame 684/863 | 2.50 FPS | ETA: 1.2 min
# Frame 685/863 | 2.50 FPS | ETA: 1.2 min
# Frame 686/863 | 2.50 FPS | ETA: 1.2 min
# Frame 687/863 | 2.50 FPS | ETA: 1.2 min
# Frame 688/863 | 2.50 FPS | ETA: 1.2 min
# Frame 689/863 | 2.50 FPS | ETA: 1.2 min
# Frame 690/863 | 2.50 FPS | ETA: 1.2 min
# Frame 691/863 | 2.50 FPS | ETA: 1.1 min
# Frame 692/863 | 2.50 FPS | ETA: 1.1 min
# Frame 693/863 | 2.50 FPS | ETA: 1.1 min
# Frame 694/863 | 2.50 FPS | ETA: 1.1 min
# Frame 695/863 | 2.50 FPS | ETA: 1.1 min
# Frame 696/863 | 2.50 FPS | ETA: 1.1 min
# Frame 697/863 | 2.50 FPS | ETA: 1.1 min
# Frame 698/863 | 2.50 FPS | ETA: 1.1 min
# Frame 699/863 | 2.50 FPS | ETA: 1.1 min
# Frame 700/863 | 2.50 FPS | ETA: 1.1 min
# Frame 701/863 | 2.50 FPS | ETA: 1.1 min
# Frame 702/863 | 2.50 FPS | ETA: 1.1 min
# Frame 703/863 | 2.50 FPS | ETA: 1.1 min
# Frame 704/863 | 2.50 FPS | ETA: 1.1 min
# Frame 705/863 | 2.50 FPS | ETA: 1.1 min
# Frame 706/863 | 2.50 FPS | ETA: 1.0 min
# Frame 707/863 | 2.50 FPS | ETA: 1.0 min
# Frame 708/863 | 2.50 FPS | ETA: 1.0 min
# Frame 709/863 | 2.50 FPS | ETA: 1.0 min
# Frame 710/863 | 2.50 FPS | ETA: 1.0 min
# Frame 711/863 | 2.50 FPS | ETA: 1.0 min
# Frame 712/863 | 2.49 FPS | ETA: 1.0 min
# Frame 713/863 | 2.49 FPS | ETA: 1.0 min
# Frame 714/863 | 2.49 FPS | ETA: 1.0 min
# Frame 715/863 | 2.49 FPS | ETA: 1.0 min
# Frame 716/863 | 2.49 FPS | ETA: 1.0 min
# Frame 717/863 | 2.49 FPS | ETA: 1.0 min
# Frame 718/863 | 2.49 FPS | ETA: 1.0 min
# Frame 719/863 | 2.49 FPS | ETA: 1.0 min
# Frame 720/863 | 2.49 FPS | ETA: 1.0 min
# Frame 721/863 | 2.49 FPS | ETA: 0.9 min
# Frame 722/863 | 2.49 FPS | ETA: 0.9 min
# Frame 723/863 | 2.49 FPS | ETA: 0.9 min
# Frame 724/863 | 2.49 FPS | ETA: 0.9 min
# Frame 725/863 | 2.49 FPS | ETA: 0.9 min
# Frame 726/863 | 2.49 FPS | ETA: 0.9 min
# Frame 727/863 | 2.49 FPS | ETA: 0.9 min
# Frame 728/863 | 2.49 FPS | ETA: 0.9 min
# Frame 729/863 | 2.49 FPS | ETA: 0.9 min
# Frame 730/863 | 2.49 FPS | ETA: 0.9 min
# Frame 731/863 | 2.49 FPS | ETA: 0.9 min
# Frame 732/863 | 2.49 FPS | ETA: 0.9 min
# Frame 733/863 | 2.49 FPS | ETA: 0.9 min
# Frame 734/863 | 2.49 FPS | ETA: 0.9 min
# Frame 735/863 | 2.49 FPS | ETA: 0.9 min
# Frame 736/863 | 2.49 FPS | ETA: 0.9 min
# Frame 737/863 | 2.49 FPS | ETA: 0.8 min
# Frame 738/863 | 2.49 FPS | ETA: 0.8 min
# Frame 739/863 | 2.49 FPS | ETA: 0.8 min
# Frame 740/863 | 2.49 FPS | ETA: 0.8 min
# Frame 741/863 | 2.49 FPS | ETA: 0.8 min
# Frame 742/863 | 2.49 FPS | ETA: 0.8 min
# Frame 743/863 | 2.49 FPS | ETA: 0.8 min
# Frame 744/863 | 2.49 FPS | ETA: 0.8 min
# Frame 745/863 | 2.49 FPS | ETA: 0.8 min
# Frame 746/863 | 2.48 FPS | ETA: 0.8 min
# Frame 747/863 | 2.48 FPS | ETA: 0.8 min
# Frame 748/863 | 2.48 FPS | ETA: 0.8 min
# Frame 749/863 | 2.48 FPS | ETA: 0.8 min
# Frame 750/863 | 2.48 FPS | ETA: 0.8 min
# Frame 751/863 | 2.48 FPS | ETA: 0.8 min
# Frame 752/863 | 2.48 FPS | ETA: 0.7 min
# Frame 753/863 | 2.48 FPS | ETA: 0.7 min
# Frame 754/863 | 2.48 FPS | ETA: 0.7 min
# Frame 755/863 | 2.48 FPS | ETA: 0.7 min
# Frame 756/863 | 2.48 FPS | ETA: 0.7 min
# Frame 757/863 | 2.48 FPS | ETA: 0.7 min
# Frame 758/863 | 2.48 FPS | ETA: 0.7 min
# Frame 759/863 | 2.48 FPS | ETA: 0.7 min
# Frame 760/863 | 2.48 FPS | ETA: 0.7 min
# Frame 761/863 | 2.48 FPS | ETA: 0.7 min
# Frame 762/863 | 2.48 FPS | ETA: 0.7 min
# Frame 763/863 | 2.48 FPS | ETA: 0.7 min
# Frame 764/863 | 2.48 FPS | ETA: 0.7 min
# Frame 765/863 | 2.48 FPS | ETA: 0.7 min
# Frame 766/863 | 2.48 FPS | ETA: 0.7 min
# Frame 767/863 | 2.48 FPS | ETA: 0.6 min
# Frame 768/863 | 2.48 FPS | ETA: 0.6 min
# Frame 769/863 | 2.48 FPS | ETA: 0.6 min
# Frame 770/863 | 2.48 FPS | ETA: 0.6 min
# Frame 771/863 | 2.48 FPS | ETA: 0.6 min
# Frame 772/863 | 2.48 FPS | ETA: 0.6 min
# Frame 773/863 | 2.48 FPS | ETA: 0.6 min
# Frame 774/863 | 2.48 FPS | ETA: 0.6 min
# Frame 775/863 | 2.48 FPS | ETA: 0.6 min
# Frame 776/863 | 2.48 FPS | ETA: 0.6 min
# Frame 777/863 | 2.48 FPS | ETA: 0.6 min
# Frame 778/863 | 2.48 FPS | ETA: 0.6 min
# Frame 779/863 | 2.48 FPS | ETA: 0.6 min
# Frame 780/863 | 2.48 FPS | ETA: 0.6 min
# Frame 781/863 | 2.48 FPS | ETA: 0.6 min
# Frame 782/863 | 2.48 FPS | ETA: 0.5 min
# Frame 783/863 | 2.48 FPS | ETA: 0.5 min
# Frame 784/863 | 2.48 FPS | ETA: 0.5 min
# Frame 785/863 | 2.48 FPS | ETA: 0.5 min
# Frame 786/863 | 2.48 FPS | ETA: 0.5 min
# Frame 787/863 | 2.48 FPS | ETA: 0.5 min
# Frame 788/863 | 2.47 FPS | ETA: 0.5 min
# Frame 789/863 | 2.47 FPS | ETA: 0.5 min
# Frame 790/863 | 2.47 FPS | ETA: 0.5 min
# Frame 791/863 | 2.47 FPS | ETA: 0.5 min
# Frame 792/863 | 2.47 FPS | ETA: 0.5 min
# Frame 793/863 | 2.47 FPS | ETA: 0.5 min
# Frame 794/863 | 2.47 FPS | ETA: 0.5 min
# Frame 795/863 | 2.47 FPS | ETA: 0.5 min
# Frame 796/863 | 2.47 FPS | ETA: 0.5 min
# Frame 797/863 | 2.47 FPS | ETA: 0.4 min
# Frame 798/863 | 2.47 FPS | ETA: 0.4 min
# Frame 799/863 | 2.47 FPS | ETA: 0.4 min
# Frame 800/863 | 2.47 FPS | ETA: 0.4 min
# Frame 801/863 | 2.47 FPS | ETA: 0.4 min
# Frame 802/863 | 2.47 FPS | ETA: 0.4 min
# Frame 803/863 | 2.47 FPS | ETA: 0.4 min
# Frame 804/863 | 2.47 FPS | ETA: 0.4 min
# Frame 805/863 | 2.47 FPS | ETA: 0.4 min
# Frame 806/863 | 2.47 FPS | ETA: 0.4 min
# Frame 807/863 | 2.47 FPS | ETA: 0.4 min
# Frame 808/863 | 2.47 FPS | ETA: 0.4 min
# Frame 809/863 | 2.47 FPS | ETA: 0.4 min
# Frame 810/863 | 2.47 FPS | ETA: 0.4 min
# Frame 811/863 | 2.47 FPS | ETA: 0.4 min
# Frame 812/863 | 2.47 FPS | ETA: 0.3 min
# Frame 813/863 | 2.47 FPS | ETA: 0.3 min
# Frame 814/863 | 2.47 FPS | ETA: 0.3 min
# Frame 815/863 | 2.47 FPS | ETA: 0.3 min
# Frame 816/863 | 2.47 FPS | ETA: 0.3 min
# Frame 817/863 | 2.47 FPS | ETA: 0.3 min
# Frame 818/863 | 2.47 FPS | ETA: 0.3 min
# Frame 819/863 | 2.47 FPS | ETA: 0.3 min
# Frame 820/863 | 2.47 FPS | ETA: 0.3 min
# Frame 821/863 | 2.47 FPS | ETA: 0.3 min
# Frame 822/863 | 2.47 FPS | ETA: 0.3 min
# Frame 823/863 | 2.47 FPS | ETA: 0.3 min
# Frame 824/863 | 2.47 FPS | ETA: 0.3 min
# Frame 825/863 | 2.47 FPS | ETA: 0.3 min
# Frame 826/863 | 2.47 FPS | ETA: 0.3 min
# Frame 827/863 | 2.47 FPS | ETA: 0.2 min
# Frame 828/863 | 2.47 FPS | ETA: 0.2 min
# Frame 829/863 | 2.47 FPS | ETA: 0.2 min
# Frame 830/863 | 2.47 FPS | ETA: 0.2 min
# Frame 831/863 | 2.47 FPS | ETA: 0.2 min
# Frame 832/863 | 2.47 FPS | ETA: 0.2 min
# Frame 833/863 | 2.47 FPS | ETA: 0.2 min
# Frame 834/863 | 2.46 FPS | ETA: 0.2 min
# Frame 835/863 | 2.46 FPS | ETA: 0.2 min
# Frame 836/863 | 2.46 FPS | ETA: 0.2 min
# Frame 837/863 | 2.46 FPS | ETA: 0.2 min
# Frame 838/863 | 2.46 FPS | ETA: 0.2 min
# Frame 839/863 | 2.46 FPS | ETA: 0.2 min
# Frame 840/863 | 2.46 FPS | ETA: 0.2 min
# Frame 841/863 | 2.46 FPS | ETA: 0.1 min
# Frame 842/863 | 2.46 FPS | ETA: 0.1 min
# Frame 843/863 | 2.46 FPS | ETA: 0.1 min
# Frame 844/863 | 2.46 FPS | ETA: 0.1 min
# Frame 845/863 | 2.46 FPS | ETA: 0.1 min
# Frame 846/863 | 2.46 FPS | ETA: 0.1 min
# Frame 847/863 | 2.46 FPS | ETA: 0.1 min
# Frame 848/863 | 2.46 FPS | ETA: 0.1 min
# Frame 849/863 | 2.46 FPS | ETA: 0.1 min
# Frame 850/863 | 2.46 FPS | ETA: 0.1 min
# Frame 851/863 | 2.46 FPS | ETA: 0.1 min
# Frame 852/863 | 2.46 FPS | ETA: 0.1 min
# Frame 853/863 | 2.46 FPS | ETA: 0.1 min
# Frame 854/863 | 2.46 FPS | ETA: 0.1 min
# Frame 855/863 | 2.46 FPS | ETA: 0.1 min
# Frame 856/863 | 2.46 FPS | ETA: 0.0 min
# Frame 857/863 | 2.46 FPS | ETA: 0.0 min
# Frame 858/863 | 2.46 FPS | ETA: 0.0 min
# Frame 859/863 | 2.46 FPS | ETA: 0.0 min
# Frame 860/863 | 2.46 FPS | ETA: 0.0 min
# Frame 861/863 | 2.46 FPS | ETA: 0.0 min
# Frame 862/863 | 2.46 FPS | ETA: 0.0 min
# Frame 863/863 | 2.46 FPS | ETA: 0.0 min
# video saved to: D:\Aldi\stairvision\src\dataset\west\videos\output_videos\output_with_mask_Copy of Copy of IMG_3093.MOV
